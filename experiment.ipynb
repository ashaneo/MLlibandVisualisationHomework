# %%
import os, sys
from pyspark.sql import SparkSession
from pyspark.ml import PipelineModel
import pandas as pd

# %%
# Ensure PySpark uses the same Python interpreter for driver and workers
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable
os.environ["PYSPARK_PYTHON"] = sys.executable

# %%
spark = SparkSession.builder \
    .appName("GenrePrediction") \
    .config("spark.sql.shuffle.partitions", "1") \
    .getOrCreate()
print(f"Running on Spark v{spark.version}")
# Out:
# Running on Spark v3.5.5

# %%
model = PipelineModel.load(f"model_stage4_merged_Trans_way_new")
label_indexer = next(
    s for s in model.stages
    if s.__class__.__name__ == "StringIndexerModel"
)
idx2label = label_indexer.labels
print("Genre labels:", idx2label)
# Out:
# Genre labels: ['pop', 'country', 'blues', 'rock', 'jazz', 'reggae', 'hip hop', 'screamo']

# %%
import pandas as pd

# 1. Load the merged dataset
merged = pd.read_csv(
    "data/Merged_dataset.csv",
    engine="python",            # fallback parser that handles uneven rows better
    on_bad_lines="skip",        # drop any line that doesn’t parse into 5 fields
    dtype=str                   # read everything as string to avoid type issues
)
# 2. Filter to only the rows where the genre is exactly "hip hop"
#    (use .str.lower() in case there’s capitalization variance)
hiphop_df1 = merged[ merged["genre"].str.lower() == "screamo" ].copy()

# %%
hiphop_df = hiphop_df1[:300]

# %%
hiphop_df.shape
# Out:
# (126, 5)

# %%
# 3. Prepare sample lyrics DataFrame
sample_sdf = spark.createDataFrame(hiphop_df)
sample_sdf.show(truncate=60)
# Out:
# +-------------------------------+--------------------------------------+------------+-------+------------------------------------------------------------+
# |                    artist_name|                            track_name|release_date|  genre|                                                      lyrics|
# +-------------------------------+--------------------------------------+------------+-------+------------------------------------------------------------+
# |Fear, and Loathing in Las Vegas|                        Return to Zero|        2017|screamo|I’m not one of them, no I ain’t I’m not one of them, no I...|
# |                         Saosin|                  3rd Measurement in C|        2003|screamo|Taking back, overdone Free and safely Souvenirs, out of s...|
# |                        Siamese|                             Chemistry|        2024|screamo|Maybe this chemistry is playing its tricks inside of me A...|
# |                   Fame on Fire|                      Spiral (Justice)|        2024|screamo|Send me into a spiral! [Verse 1] I did my best to avoid a...|
# |             The Early November|                I Want To Hear You Sad|        2002|screamo|These eyes They're strongly covered in disguise They're w...|
# |           Funeral For A Friend|                    Roses for the Dead|        2005|screamo|Just to say we're sorry For the black eyes and bleeding l...|
# |                  Amber Pacific|                            Always You|        2004|screamo|Inside my heart for you and I I won't forget these tears ...|
# |                    Silverstein|                               The End|        2009|screamo|Shane Told revealed at an acoustic River Oaks show that “...|
# |              Hands Like Houses|                          Overthinking|        2018|screamo|I could have just held my tongue I should have just fille...|
# |              A Day To Remember|                       Looks Like Hell|        2021|screamo|Yeah, that's why I can't tell you things What's been weig...|
# |                 Young Medicine|                        Winter Soldier|        2024|screamo|With every step I hear you calling out Are we falling out...|
# |                         Saosin|                  Translating the Name|        2003|screamo|Oh, start saving green and before breathing I have your v...|
# |              A Day To Remember|                    You Had Me @ Hello|        2008|screamo|… Read More [Verse 1] I'm missing you so much, I'll say y...|
# |              Story Of The Year|                               Wake Up|        2008|screamo|We are alive for a moment One second in the great abyss o...|
# |              A Day To Remember|                            I Remember|        2013|screamo|I'd never wish any of this on anyone or anything Aw come ...|
# |              A Day To Remember|               Leave All The Lights On|        2013|screamo|Guess things didn't go the way that you planned I missed ...|
# |Fear, and Loathing in Las Vegas|                            Party Boys|        2015|screamo|We have confidence to make You guys, guys, you guys enjoy...|
# |                    Silverstein|           Your Sword Versus My Dagger|        2005|screamo|The track is a pure reference to the tragedy “Romeo and… ...|
# |                Pierce The Veil|Karma Police - triple j Like A Version|        2023|screamo|Karma police, arrest this man, he talks in maths He buzze...|
# |              Dance Gavin Dance|                         Feels Bad Man|        2022|screamo|Whoa, you're alive Do you ever really stop and wonder why...|
# +-------------------------------+--------------------------------------+------------+-------+------------------------------------------------------------+
# only showing top 20 rows

# %%
# 4. Run model to predict genres
predictions = model.transform(sample_sdf)
results = predictions.select(
    "artist_name", "track_name", "lyrics", "probability", "prediction"
)
for row in results.collect():
    artist = row['artist_name']
    title = row['track_name']
    probs = row['probability'].toArray().tolist()
    pred = idx2label[int(row['prediction'])]
    print(f"{artist} - {title}")
    print(f"  → Predicted genre: {pred}")
    print(f"  Probabilities: {dict(zip(idx2label, [round(p,3) for p in probs]))}\n")
# Out:
# Fear, and Loathing in Las Vegas - Return to Zero
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.259, 'country': 0.18, 'blues': 0.173, 'rock': 0.13, 'jazz': 0.143, 'reggae': 0.078, 'hip hop': 0.015, 'screamo': 0.021}
#
# Saosin - 3rd Measurement in C
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.055, 'country': 0.045, 'blues': 0.04, 'rock': 0.03, 'jazz': 0.03, 'reggae': 0.018, 'hip hop': 0.003, 'screamo': 0.78}
#
# Siamese - Chemistry
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.032, 'country': 0.022, 'blues': 0.023, 'rock': 0.024, 'jazz': 0.02, 'reggae': 0.011, 'hip hop': 0.002, 'screamo': 0.866}
#
# Fame on Fire - Spiral (Justice)
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.001, 'blues': 0.001, 'rock': 0.002, 'jazz': 0.001, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.994}
#
# The Early November - I Want To Hear You Sad
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.033, 'country': 0.03, 'blues': 0.026, 'rock': 0.02, 'jazz': 0.022, 'reggae': 0.011, 'hip hop': 0.002, 'screamo': 0.855}
#
# Funeral For A Friend - Roses for the Dead
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.02, 'country': 0.016, 'blues': 0.014, 'rock': 0.011, 'jazz': 0.013, 'reggae': 0.008, 'hip hop': 0.002, 'screamo': 0.915}
#
# Amber Pacific - Always You
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.299, 'country': 0.255, 'blues': 0.139, 'rock': 0.112, 'jazz': 0.116, 'reggae': 0.06, 'hip hop': 0.012, 'screamo': 0.007}
#
# Silverstein - The End
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 1.0}
#
# Hands Like Houses - Overthinking
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.001, 'blues': 0.001, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.997}
#
# A Day To Remember - Looks Like Hell
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.003, 'country': 0.002, 'blues': 0.002, 'rock': 0.001, 'jazz': 0.002, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.988}
#
# Young Medicine - Winter Soldier
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.009, 'country': 0.006, 'blues': 0.007, 'rock': 0.005, 'jazz': 0.006, 'reggae': 0.003, 'hip hop': 0.001, 'screamo': 0.964}
#
# Saosin - Translating the Name
#   → Predicted genre: jazz
#   Probabilities: {'pop': 0.13, 'country': 0.113, 'blues': 0.093, 'rock': 0.07, 'jazz': 0.394, 'reggae': 0.047, 'hip hop': 0.011, 'screamo': 0.142}
#
# A Day To Remember - You Had Me @ Hello
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.998}
#
# Story Of The Year - Wake Up
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 1.0}
#
# A Day To Remember - I Remember
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.093, 'country': 0.09, 'blues': 0.035, 'rock': 0.042, 'jazz': 0.045, 'reggae': 0.028, 'hip hop': 0.005, 'screamo': 0.662}
#
# A Day To Remember - Leave All The Lights On
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.037, 'country': 0.025, 'blues': 0.02, 'rock': 0.015, 'jazz': 0.016, 'reggae': 0.009, 'hip hop': 0.002, 'screamo': 0.875}
#
# Fear, and Loathing in Las Vegas - Party Boys
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.259, 'country': 0.129, 'blues': 0.178, 'rock': 0.149, 'jazz': 0.155, 'reggae': 0.1, 'hip hop': 0.018, 'screamo': 0.011}
#
# Silverstein - Your Sword Versus My Dagger
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.012, 'country': 0.009, 'blues': 0.008, 'rock': 0.006, 'jazz': 0.006, 'reggae': 0.005, 'hip hop': 0.001, 'screamo': 0.954}
#
# Pierce The Veil - Karma Police - triple j Like A Version
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.133, 'country': 0.114, 'blues': 0.1, 'rock': 0.075, 'jazz': 0.086, 'reggae': 0.049, 'hip hop': 0.01, 'screamo': 0.433}
#
# Dance Gavin Dance - Feels Bad Man
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.079, 'country': 0.067, 'blues': 0.059, 'rock': 0.046, 'jazz': 0.049, 'reggae': 0.027, 'hip hop': 0.005, 'screamo': 0.668}
#
# Phonefoot - real spill
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.267, 'country': 0.19, 'blues': 0.171, 'rock': 0.13, 'jazz': 0.141, 'reggae': 0.074, 'hip hop': 0.014, 'screamo': 0.012}
#
# Matchbook Romance - My Eyes Burn
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.007, 'country': 0.01, 'blues': 0.005, 'rock': 0.004, 'jazz': 0.004, 'reggae': 0.002, 'hip hop': 0.0, 'screamo': 0.967}
#
# Issues - Disappear (Remember When)
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.016, 'country': 0.006, 'blues': 0.005, 'rock': 0.004, 'jazz': 0.004, 'reggae': 0.003, 'hip hop': 0.001, 'screamo': 0.961}
#
# Dance Gavin Dance - Alex English
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.16, 'country': 0.162, 'blues': 0.084, 'rock': 0.068, 'jazz': 0.065, 'reggae': 0.038, 'hip hop': 0.007, 'screamo': 0.416}
#
# Attack Attack! - All My Life
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.027, 'country': 0.023, 'blues': 0.017, 'rock': 0.015, 'jazz': 0.017, 'reggae': 0.011, 'hip hop': 0.002, 'screamo': 0.889}
#
# The Red Jumpsuit Apparatus - Face Down (Alliance Edition)
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.266, 'country': 0.175, 'blues': 0.167, 'rock': 0.13, 'jazz': 0.146, 'reggae': 0.092, 'hip hop': 0.02, 'screamo': 0.004}
#
# Pierce The Veil - Bulletproof Love
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.012, 'country': 0.007, 'blues': 0.007, 'rock': 0.006, 'jazz': 0.006, 'reggae': 0.004, 'hip hop': 0.001, 'screamo': 0.958}
#
# Thrice - In Exile
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.042, 'country': 0.035, 'blues': 0.028, 'rock': 0.021, 'jazz': 0.023, 'reggae': 0.012, 'hip hop': 0.002, 'screamo': 0.837}
#
# The Used - Take It Away
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.006, 'country': 0.005, 'blues': 0.003, 'rock': 0.003, 'jazz': 0.004, 'reggae': 0.002, 'hip hop': 0.0, 'screamo': 0.978}
#
# Scary Kids Scaring Kids - The Only Medicine
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.207, 'country': 0.174, 'blues': 0.153, 'rock': 0.117, 'jazz': 0.126, 'reggae': 0.069, 'hip hop': 0.013, 'screamo': 0.14}
#
# Sleeping With Sirens - Be Happy (feat. Royal & the Serpent)
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 1.0}
#
# Atreyu - Bleeding Mascara
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.094, 'country': 0.08, 'blues': 0.067, 'rock': 0.05, 'jazz': 0.057, 'reggae': 0.032, 'hip hop': 0.007, 'screamo': 0.612}
#
# Pierce The Veil - Flawless Execution
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.038, 'country': 0.031, 'blues': 0.028, 'rock': 0.022, 'jazz': 0.025, 'reggae': 0.013, 'hip hop': 0.003, 'screamo': 0.84}
#
# Ghost Atlas - Lesser Gods
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.101, 'country': 0.101, 'blues': 0.09, 'rock': 0.061, 'jazz': 0.064, 'reggae': 0.035, 'hip hop': 0.007, 'screamo': 0.541}
#
# Silverstein - Skin & Bones
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.025, 'country': 0.018, 'blues': 0.015, 'rock': 0.012, 'jazz': 0.029, 'reggae': 0.007, 'hip hop': 0.001, 'screamo': 0.892}
#
# Febuary - No Way...
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.233, 'country': 0.213, 'blues': 0.182, 'rock': 0.136, 'jazz': 0.14, 'reggae': 0.079, 'hip hop': 0.015, 'screamo': 0.003}
#
# The Fall of Troy - I Just Got This Symphony Goin'
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.004, 'country': 0.003, 'blues': 0.003, 'rock': 0.002, 'jazz': 0.002, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.984}
#
# The Used - Wake the Dead
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.037, 'country': 0.011, 'blues': 0.021, 'rock': 0.018, 'jazz': 0.043, 'reggae': 0.012, 'hip hop': 0.002, 'screamo': 0.855}
#
# The Used - With Me Tonight
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.001, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.001, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.998}
#
# Alexisonfire - Born and Raised
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.01, 'country': 0.009, 'blues': 0.007, 'rock': 0.006, 'jazz': 0.006, 'reggae': 0.005, 'hip hop': 0.001, 'screamo': 0.956}
#
# Silverstein - Fist Wrapped In Blood
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.011, 'country': 0.009, 'blues': 0.008, 'rock': 0.007, 'jazz': 0.006, 'reggae': 0.004, 'hip hop': 0.001, 'screamo': 0.954}
#
# Scary Kids Scaring Kids - Degenerates
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.249, 'country': 0.183, 'blues': 0.163, 'rock': 0.128, 'jazz': 0.153, 'reggae': 0.098, 'hip hop': 0.022, 'screamo': 0.004}
#
# Escape the Fate - Harder Than You Know
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 1.0}
#
# Chiodos - There's No Penguins In Alaska
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.223, 'country': 0.178, 'blues': 0.175, 'rock': 0.14, 'jazz': 0.145, 'reggae': 0.076, 'hip hop': 0.015, 'screamo': 0.048}
#
# Eyes Set To Kill - Broken Frames
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.254, 'country': 0.183, 'blues': 0.179, 'rock': 0.145, 'jazz': 0.138, 'reggae': 0.077, 'hip hop': 0.015, 'screamo': 0.007}
#
# The Red Jumpsuit Apparatus - Face Down - Symphonic Edition
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.997}
#
# Escape the Fate - Reverse This Curse
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.011, 'country': 0.008, 'blues': 0.005, 'rock': 0.004, 'jazz': 0.004, 'reggae': 0.003, 'hip hop': 0.0, 'screamo': 0.964}
#
# Sleeping With Sirens - Bloody Knuckles
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.006, 'country': 0.004, 'blues': 0.003, 'rock': 0.003, 'jazz': 0.003, 'reggae': 0.002, 'hip hop': 0.0, 'screamo': 0.978}
#
# Saosin - Sleepers
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.037, 'country': 0.028, 'blues': 0.025, 'rock': 0.02, 'jazz': 0.021, 'reggae': 0.011, 'hip hop': 0.002, 'screamo': 0.856}
#
# Dance Gavin Dance - Flossie Dickey Bounce
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.042, 'country': 0.045, 'blues': 0.028, 'rock': 0.023, 'jazz': 0.024, 'reggae': 0.014, 'hip hop': 0.003, 'screamo': 0.822}
#
# Dance Gavin Dance - Story Of My Bros
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.997}
#
# Story Of The Year - Tear Me to Pieces
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 1.0}
#
# Circa Survive - Get Out
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.18, 'country': 0.144, 'blues': 0.14, 'rock': 0.105, 'jazz': 0.116, 'reggae': 0.064, 'hip hop': 0.012, 'screamo': 0.239}
#
# Senses Fail - Rum Is for Drinking, Not for Burning
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.006, 'country': 0.005, 'blues': 0.005, 'rock': 0.004, 'jazz': 0.004, 'reggae': 0.002, 'hip hop': 0.0, 'screamo': 0.973}
#
# The Red Jumpsuit Apparatus - Wake Me Up
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.113, 'country': 0.092, 'blues': 0.076, 'rock': 0.059, 'jazz': 0.066, 'reggae': 0.038, 'hip hop': 0.007, 'screamo': 0.549}
#
# Circa Survive - Act Appalled
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.004, 'country': 0.003, 'blues': 0.003, 'rock': 0.002, 'jazz': 0.002, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.984}
#
# Catalyst... - forget it ill figure it out
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.057, 'country': 0.024, 'blues': 0.039, 'rock': 0.031, 'jazz': 0.034, 'reggae': 0.019, 'hip hop': 0.004, 'screamo': 0.792}
#
# Brand New - Mix Tape
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.021, 'country': 0.014, 'blues': 0.014, 'rock': 0.011, 'jazz': 0.012, 'reggae': 0.008, 'hip hop': 0.002, 'screamo': 0.918}
#
# Dance Gavin Dance - Pray To God For Your Mother
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.998}
#
# Just Surrender - Your Life and Mine
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.285, 'country': 0.195, 'blues': 0.143, 'rock': 0.122, 'jazz': 0.12, 'reggae': 0.071, 'hip hop': 0.013, 'screamo': 0.051}
#
# The Used - Bulimic
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.022, 'country': 0.016, 'blues': 0.015, 'rock': 0.012, 'jazz': 0.013, 'reggae': 0.007, 'hip hop': 0.001, 'screamo': 0.914}
#
# Brand New - (Fork And Knife)
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.077, 'country': 0.055, 'blues': 0.049, 'rock': 0.032, 'jazz': 0.041, 'reggae': 0.025, 'hip hop': 0.006, 'screamo': 0.715}
#
# Brand New - I Am A Nightmare
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.066, 'country': 0.058, 'blues': 0.05, 'rock': 0.036, 'jazz': 0.041, 'reggae': 0.025, 'hip hop': 0.004, 'screamo': 0.72}
#
# Sólstafir - Fjara
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.218, 'country': 0.198, 'blues': 0.177, 'rock': 0.132, 'jazz': 0.146, 'reggae': 0.097, 'hip hop': 0.015, 'screamo': 0.017}
#
# Finch - Letters To You
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.019, 'country': 0.011, 'blues': 0.009, 'rock': 0.007, 'jazz': 0.007, 'reggae': 0.004, 'hip hop': 0.001, 'screamo': 0.943}
#
# Chiodos - The Undertaker's Thirst For Revenge Is Unquenchable. (The Final Battle)
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.001, 'blues': 0.001, 'rock': 0.0, 'jazz': 0.001, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.996}
#
# Dance Gavin Dance - Antlion
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.034, 'country': 0.02, 'blues': 0.02, 'rock': 0.015, 'jazz': 0.016, 'reggae': 0.034, 'hip hop': 0.002, 'screamo': 0.859}
#
# Silverstein - Bankrupt
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.998}
#
# Pierce The Veil - The Sky Under the Sea
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.014, 'country': 0.011, 'blues': 0.009, 'rock': 0.007, 'jazz': 0.007, 'reggae': 0.004, 'hip hop': 0.001, 'screamo': 0.947}
#
# Sleeping With Sirens - Fly
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.03, 'country': 0.016, 'blues': 0.013, 'rock': 0.013, 'jazz': 0.011, 'reggae': 0.006, 'hip hop': 0.001, 'screamo': 0.91}
#
# Thrice - Paper Tigers
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.076, 'country': 0.068, 'blues': 0.059, 'rock': 0.045, 'jazz': 0.05, 'reggae': 0.026, 'hip hop': 0.005, 'screamo': 0.672}
#
# Dance Gavin Dance - Shelf Life
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.069, 'country': 0.058, 'blues': 0.046, 'rock': 0.036, 'jazz': 0.04, 'reggae': 0.023, 'hip hop': 0.005, 'screamo': 0.723}
#
# Fame on Fire - Nightmare (The Devil)
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 1.0}
#
# A Day To Remember - The Danger In Starting A Fire
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.14, 'country': 0.104, 'blues': 0.08, 'rock': 0.067, 'jazz': 0.076, 'reggae': 0.044, 'hip hop': 0.009, 'screamo': 0.48}
#
# A Day To Remember - Here's To The Past
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.997}
#
# Pierce The Veil - Even When I’m Not With You
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.002, 'country': 0.002, 'blues': 0.001, 'rock': 0.001, 'jazz': 0.001, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.994}
#
# Alexisonfire - Hey, It's Your Funeral Mama
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.013, 'country': 0.008, 'blues': 0.01, 'rock': 0.008, 'jazz': 0.009, 'reggae': 0.005, 'hip hop': 0.001, 'screamo': 0.946}
#
# Four Year Strong - She's So High
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.118, 'country': 0.074, 'blues': 0.061, 'rock': 0.058, 'jazz': 0.066, 'reggae': 0.044, 'hip hop': 0.009, 'screamo': 0.57}
#
# Every Time I Die - We'rewolf
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.261, 'country': 0.248, 'blues': 0.135, 'rock': 0.153, 'jazz': 0.112, 'reggae': 0.077, 'hip hop': 0.012, 'screamo': 0.003}
#
# The Used - Poetic Tragedy
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.013, 'country': 0.01, 'blues': 0.009, 'rock': 0.007, 'jazz': 0.007, 'reggae': 0.004, 'hip hop': 0.001, 'screamo': 0.949}
#
# I See Stars - D4MAGE DONE
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.043, 'country': 0.034, 'blues': 0.029, 'rock': 0.019, 'jazz': 0.023, 'reggae': 0.029, 'hip hop': 0.004, 'screamo': 0.819}
#
# Brand New - Magazines
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.056, 'country': 0.029, 'blues': 0.023, 'rock': 0.019, 'jazz': 0.021, 'reggae': 0.011, 'hip hop': 0.002, 'screamo': 0.84}
#
# Written by Wolves - GODDESS
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.999}
#
# Dance Gavin Dance - Count Bassy
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.065, 'country': 0.104, 'blues': 0.046, 'rock': 0.039, 'jazz': 0.039, 'reggae': 0.025, 'hip hop': 0.005, 'screamo': 0.677}
#
# Thrice - Hurricane
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.154, 'country': 0.131, 'blues': 0.114, 'rock': 0.088, 'jazz': 0.098, 'reggae': 0.057, 'hip hop': 0.011, 'screamo': 0.348}
#
# Pierce The Veil - Coming Clean
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.021, 'country': 0.035, 'blues': 0.016, 'rock': 0.013, 'jazz': 0.014, 'reggae': 0.007, 'hip hop': 0.001, 'screamo': 0.893}
#
# Emarosa - The Past Should Stay Dead
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.005, 'country': 0.003, 'blues': 0.003, 'rock': 0.002, 'jazz': 0.003, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.982}
#
# The Used - The Bird and the Worm
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.037, 'country': 0.033, 'blues': 0.018, 'rock': 0.022, 'jazz': 0.051, 'reggae': 0.022, 'hip hop': 0.013, 'screamo': 0.805}
#
# Haste The Day - When Everything Falls
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.998}
#
# An Evening At Elmwood - Secrets
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.022, 'country': 0.011, 'blues': 0.014, 'rock': 0.01, 'jazz': 0.011, 'reggae': 0.006, 'hip hop': 0.001, 'screamo': 0.925}
#
# Famous Last Words - The Show Must Go on Prt. 2
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.228, 'country': 0.194, 'blues': 0.165, 'rock': 0.147, 'jazz': 0.151, 'reggae': 0.095, 'hip hop': 0.015, 'screamo': 0.006}
#
# I See Stars - SPLIT
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.127, 'country': 0.103, 'blues': 0.099, 'rock': 0.083, 'jazz': 0.08, 'reggae': 0.043, 'hip hop': 0.008, 'screamo': 0.457}
#
# Anthony Green - Don't Dance
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.108, 'country': 0.089, 'blues': 0.07, 'rock': 0.052, 'jazz': 0.063, 'reggae': 0.041, 'hip hop': 0.011, 'screamo': 0.565}
#
# Underoath - Down, Set, Go
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.006, 'country': 0.008, 'blues': 0.004, 'rock': 0.003, 'jazz': 0.003, 'reggae': 0.002, 'hip hop': 0.0, 'screamo': 0.974}
#
# Burial Etiquette - Faceless Departure
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.225, 'country': 0.196, 'blues': 0.175, 'rock': 0.131, 'jazz': 0.145, 'reggae': 0.075, 'hip hop': 0.015, 'screamo': 0.038}
#
# Saosin - Lost Symphonies
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.109, 'country': 0.099, 'blues': 0.088, 'rock': 0.066, 'jazz': 0.072, 'reggae': 0.038, 'hip hop': 0.007, 'screamo': 0.52}
#
# Saosin - Deep Down
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.033, 'country': 0.045, 'blues': 0.024, 'rock': 0.018, 'jazz': 0.046, 'reggae': 0.012, 'hip hop': 0.003, 'screamo': 0.821}
#
# blessthefall - Guys Like You Make Us Look Bad
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.24, 'country': 0.135, 'blues': 0.157, 'rock': 0.118, 'jazz': 0.126, 'reggae': 0.068, 'hip hop': 0.013, 'screamo': 0.142}
#
# Every Time I Die - Post-Boredom
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.284, 'country': 0.207, 'blues': 0.156, 'rock': 0.122, 'jazz': 0.131, 'reggae': 0.075, 'hip hop': 0.014, 'screamo': 0.011}
#
# Written by Wolves - Pretty Lies
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.018, 'country': 0.011, 'blues': 0.012, 'rock': 0.01, 'jazz': 0.011, 'reggae': 0.006, 'hip hop': 0.001, 'screamo': 0.931}
#
# Pierce The Veil - Shared Trauma
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.042, 'country': 0.039, 'blues': 0.028, 'rock': 0.025, 'jazz': 0.026, 'reggae': 0.014, 'hip hop': 0.003, 'screamo': 0.823}
#
# Every Time I Die - It Remembers
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.002, 'country': 0.002, 'blues': 0.002, 'rock': 0.001, 'jazz': 0.001, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.99}
#
# Dance Gavin Dance - Purple Reign
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.013, 'country': 0.011, 'blues': 0.009, 'rock': 0.007, 'jazz': 0.008, 'reggae': 0.007, 'hip hop': 0.001, 'screamo': 0.942}
#
# Underoath - Too Bright To See, Too Loud To Hear
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.126, 'country': 0.114, 'blues': 0.102, 'rock': 0.076, 'jazz': 0.083, 'reggae': 0.044, 'hip hop': 0.009, 'screamo': 0.446}
#
# The Used - Cry
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.998}
#
# Circa Survive - In The Morning And Amazing...
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.147, 'country': 0.106, 'blues': 0.094, 'rock': 0.071, 'jazz': 0.091, 'reggae': 0.041, 'hip hop': 0.008, 'screamo': 0.441}
#
# Dance Gavin Dance - Legend
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.003, 'country': 0.003, 'blues': 0.002, 'rock': 0.002, 'jazz': 0.002, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.986}
#
# Underoath - Hallelujah
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.086, 'country': 0.054, 'blues': 0.055, 'rock': 0.045, 'jazz': 0.103, 'reggae': 0.024, 'hip hop': 0.005, 'screamo': 0.627}
#
# Sugarcult - Stuck In America
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.264, 'country': 0.174, 'blues': 0.13, 'rock': 0.15, 'jazz': 0.161, 'reggae': 0.085, 'hip hop': 0.023, 'screamo': 0.013}
#
# Four Year Strong - Love Song
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.001, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.997}
#
# Sleeping With Sirens - Scene Three - Stomach Tied In Knots
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.072, 'country': 0.048, 'blues': 0.038, 'rock': 0.032, 'jazz': 0.035, 'reggae': 0.025, 'hip hop': 0.004, 'screamo': 0.746}
#
# Brand New - Last Chance To Lose Your Keys
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.005, 'country': 0.002, 'blues': 0.003, 'rock': 0.001, 'jazz': 0.001, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.987}
#
# A Day To Remember - Good Things
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.009, 'country': 0.007, 'blues': 0.006, 'rock': 0.005, 'jazz': 0.005, 'reggae': 0.003, 'hip hop': 0.001, 'screamo': 0.965}
#
# Atreyu - Insomnia
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.001, 'blues': 0.001, 'rock': 0.001, 'jazz': 0.001, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.995}
#
# Senses Fail - Tie Her Down
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.142, 'country': 0.13, 'blues': 0.098, 'rock': 0.075, 'jazz': 0.08, 'reggae': 0.047, 'hip hop': 0.009, 'screamo': 0.42}
#
# Glassjaw - Mu Empire
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.166, 'country': 0.143, 'blues': 0.132, 'rock': 0.099, 'jazz': 0.109, 'reggae': 0.058, 'hip hop': 0.011, 'screamo': 0.283}
#
# Issues - The Realest
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.01, 'country': 0.004, 'blues': 0.007, 'rock': 0.004, 'jazz': 0.005, 'reggae': 0.003, 'hip hop': 0.001, 'screamo': 0.967}
#
# Broadway - Same Thing We Do Everyday Pinky
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.026, 'country': 0.021, 'blues': 0.019, 'rock': 0.014, 'jazz': 0.015, 'reggae': 0.009, 'hip hop': 0.002, 'screamo': 0.895}
#
# I See Stars - Mobbin' Out
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.0, 'country': 0.0, 'blues': 0.0, 'rock': 0.0, 'jazz': 0.0, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.998}
#
# Thrice - All That's Left
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.059, 'country': 0.049, 'blues': 0.045, 'rock': 0.092, 'jazz': 0.037, 'reggae': 0.019, 'hip hop': 0.004, 'screamo': 0.695}
#
# Underoath - Young And Aspiring
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.021, 'country': 0.016, 'blues': 0.015, 'rock': 0.011, 'jazz': 0.012, 'reggae': 0.007, 'hip hop': 0.002, 'screamo': 0.917}
#
# From First To Last - Secrets Don't Make Friends
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.004, 'country': 0.003, 'blues': 0.003, 'rock': 0.002, 'jazz': 0.002, 'reggae': 0.001, 'hip hop': 0.0, 'screamo': 0.984}
#
# AFI - Paper Airplanes (Makeshift Wings)
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.001, 'country': 0.001, 'blues': 0.001, 'rock': 0.001, 'jazz': 0.001, 'reggae': 0.0, 'hip hop': 0.0, 'screamo': 0.996}
#
# Emery - Walls
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.018, 'country': 0.016, 'blues': 0.013, 'rock': 0.014, 'jazz': 0.01, 'reggae': 0.006, 'hip hop': 0.001, 'screamo': 0.924}
#
# Glassjaw - Cosmopolitan Blood Loss
#   → Predicted genre: screamo
#   Probabilities: {'pop': 0.098, 'country': 0.085, 'blues': 0.078, 'rock': 0.059, 'jazz': 0.063, 'reggae': 0.067, 'hip hop': 0.007, 'screamo': 0.544}
#
# A Skylit Drive - Rise
#   → Predicted genre: pop
#   Probabilities: {'pop': 0.269, 'country': 0.19, 'blues': 0.161, 'rock': 0.134, 'jazz': 0.143, 'reggae': 0.081, 'hip hop': 0.017, 'screamo': 0.005}

# %% [markdown]
# # Songs for video

# %%
import pandas as pd

# %%
merged = pd.read_csv(
    "data/Merged_dataset.csv",
    engine="python",            # fallback parser that handles uneven rows better
    on_bad_lines="skip",        # drop any line that doesn’t parse into 5 fields
    dtype=str                   # read everything as string to avoid type issues
)

# %%
POP = merged[ merged["track_name"].str.lower() == "mohabbat bhi jhoothi" ].copy()

# %%
POP
# Out:
#   artist_name            track_name release_date genre  \
# 0      mukesh  mohabbat bhi jhoothi         1950   pop
#
#                                               lyrics
# 0  hold time feel break feel untrue convince spea...

# %%
BLUES = merged[ merged["track_name"].str.lower() == "a woman is a sometime thing" ].copy()

# %%
BLUES
# Out:
#            artist_name                   track_name release_date  genre  \
# 12732  ella fitzgerald  a woman is a sometime thing         1958  blues
#
#                                                   lyrics
# 12732  lissen daddy warn fore start atravelling woman...

# %%
REGGEA = merged[ merged["track_name"].str.lower() == "only jah jah know" ].copy()

# %%
REGGEA
# Out:
#       artist_name         track_name release_date   genre  \
# 21169     tetrack  only jah jah know         1978  reggae
#
#                                                   lyrics
# 21169  irie souljah come tell enemie friend learn gro...

# %%
ROCK = merged[ merged["track_name"].str.lower() == "here, there and everywhere" ].copy()

# %%
ROCK
# Out:
#           artist_name                  track_name release_date genre  \
# 1998   emmylou harris  here, there and everywhere         1975   pop
# 18861   george benson  here, there and everywhere         1989  jazz
# 23659     the beatles  here, there and everywhere         1966  rock
#
#                                                   lyrics
# 1998   make year change life wave hand run hand hair ...
# 18861  lead better life need make year change life wa...
# 23659  lead better life need make year change life wa...

# %%
screamo = merged[ merged["track_name"] == "Chemistry" ].copy()

# %%
screamo
# Out:
#       artist_name track_name release_date    genre  \
# 28275     Siamese  Chemistry         2024  screamo
#
#                                                   lyrics
# 28275  Maybe this chemistry is playing its tricks ins...

# %%
here, there and everywhere

# %%
only jah jah know

# %%
a woman is a sometime thing

# %%
mohabbat bhi jhoothi
